# %% [markdown]
# ## Running the Offline Evaluations for the Report Generation Agent
#
# Offline evaluations are evaluations run against a **pre-defined dataset**. It performs **detailed evaluations** of the **outputs** of the agentic system and the **steps** it has taken to produce those evaluations.
#
# This dataset is called the **expected results** or the **ground-truth** dataset, and on this case it's a **handcrafted** dataset with **inputs, outputs and trajectory** for a few known use cases.
#
# The evaluations are run by Langfuse and the results are visualized there.

# %% [markdown]
# ## Setting up
#
# The code below sets the notebook default folder, sets the default constants and checks the presence of the environment variables.
#
# The environment variables can be set in the `.env` file in the root folder of the project.

# %%
import json
import os
from pathlib import Path
from pprint import pprint

from aieng.agent_evals.async_client_manager import AsyncClientManager
from aieng.agent_evals.langfuse import upload_dataset_to_langfuse


# Setting the notebook directory to the project's root folder
if Path("").absolute().name == "eval-agents":
    print(f"Notebook path is already the root path: {Path('').absolute()}")
else:
    os.chdir(Path("").absolute().parent.parent)
    print(f"The notebook path has been set to: {Path('').absolute()}")

client_manager = AsyncClientManager.get_instance()
assert client_manager.configs.report_generation_db.database, (
    "[ERROR] The database path is not set! Please configure the REPORT_GENERATION_DB__DATABASE environment variable."
)
assert client_manager.configs.langfuse_secret_key, (
    "[ERROR] The Langfuse secret key is not set! Please configure the LANGFUSE_SECRET_KEY environment variable."
)
assert client_manager.configs.langfuse_public_key, (
    "[ERROR] The Langfuse public key is not set! Please configure the LANGFUSE_PUBLIC_KEY environment variable."
)
assert client_manager.configs.langfuse_host, (
    "[ERROR] The Langfuse base URL is not set! Please configure the LANGFUSE_HOST environment variable."
)

print("All environment variables have been set.")


EVALUATION_DATASET_PATH = "implementations/report_generation/data/OnlineRetailReportEval.json"
LANGFUSE_DATASET_NAME = "OnlineRetailReportEval"
# Out:
# The notebook path has been set to: /home/coder/eval-agents
# All environment variables have been set.

# %% [markdown]
# ## Taking a Look at the Ground Truth Dataset
#
# The ground-truth dataset is located at `implementations/report_generation/data/OnlineRetailReportEval.json`. The code below will display one of its elements as an example:

# %%
with open("implementations/report_generation/data/OnlineRetailReportEval.json") as f:
    ground_truth = json.load(f)

print(f"Ground-truth dataset size: {len(ground_truth)}")
print("First element:")
pprint(ground_truth[0])
# Out:
# Ground-truth dataset size: 7
# First element:
# {'expected_output': {'final_report': {'filename': 'monthly_sales_performance_report.xlsx',
#                                       'report_columns': ['SalesMonth',
#                                                          'TotalSales'],
#                                       'report_data': [['2010-12', 748957.02],
#                                                       ['2011-01', 560000.26],
#                                                       ['2011-02', 498062.65],
#                                                       ['2011-03', 683267.08],
#                                                       ['2011-04', 493207.12],
#                                                       ['2011-05', 723333.51],
#                                                       ['2011-06', 691123.12],
#                                                       ['2011-07', 681300.11],
#                                                       ['2011-08', 682680.51],
#                                                       ['2011-09', 1019687.62],
#                                                       ['2011-10', 1070704.67],
#                                                       ['2011-11', 1461756.25],
#                                                       ['2011-12', 433668.01]]},
#                      'trajectory': {'actions': ['get_schema_info',
#                                                 'execute',
#                                                 'execute',
#                                                 'write_xlsx',
#                                                 'output_text'],
#                                     'description': ['Check what are the tables '
#                                                     'that are available in the '
#                                                     'database',
#                                                     'Check what are the '
#                                                     'columns that are '
#                                                     'available in the sales '
#                                                     'table',
#                                                     'Query to retrieve the '
#                                                     'sales performance '
#                                                     '(quantity * price) per '
#                                                     'month',
#                                                     'Send the report data to '
#                                                     'the function that writes '
#                                                     'the report to disk',
#                                                     'Output text to the user '
#                                                     'with the report file as a '
#                                                     'Gradio hyperlink']}},
#  'id': '1',
#  'input': 'Generate a monthly sales performance report.'}

# %% [markdown]
# Here is an explanation of the data structure of the dataset samples:
# ```python
# {
#     'id': str,  # The ID of the sample
#     'input': str,  # The input to be used to test the report generation agent
#     'expected_output': {  # The expected outputs of the agent
#         'final_report': {  # The output data for the final report the agent generates.
#                            # These values match the input the agent sends to the `write_xlsx` function
#             'filename': str,  # The name of the report file
#             'report_columns': list[str,  # The names of the columns of the report
#             'report_data': list[list[Any]],  # a bidimensional array of values for the rows of the report
#         }
#         'trajectory': {  # information about the trajectory the agent should take to produce the report
#             'actions': list[str],  # A list of the names of the actions the agent should take, in order
#             'description': list[str],  # A description of what the parameters that are sent to each one of
#                                        # the actions are supposed to be doing
#         }
#     }
# }
# ```

# %% [markdown]
# ## Uploading the dataset to Langfuse
#
# Use the function below to **upload** the ground truth dataset to Langfuse so it can be used **during the evaluation**:

# %%
await upload_dataset_to_langfuse(
    EVALUATION_DATASET_PATH,
    LANGFUSE_DATASET_NAME,
)
# Out:
# 2026-03-24 05:13:10,473 INFO aieng.agent_evals.langfuse: Loading dataset from 'implementations/report_generation/data/OnlineRetailReportEval.json'
# Uploading Langfuse dataset 'OnlineRetailReportEval' ━━━━━━━━ 7/7 0:00:00 0:00:01m 0:00:01
# 2026-03-24 05:13:11,826 INFO aieng.agent_evals.langfuse: Uploaded 7 items to dataset 'OnlineRetailReportEval'

# %% [markdown]
# ## LLM-as-a-judge Evaluators
#
# Two **LLM-as-a-judge evaluators** are set to run against this dataset and the agent's output:
# 1. A **Final Result Evaluator**, that will evaluate the agent's output against the contents of the `final_result` key
# 2. A **Trajectory Evaluator**, that will evaluate the agent's output against the contents of the `trajectory` key
#
# Here are the instructions for both of those agents (as per `aieng.agent_evals.evaluation.report_generation.prompts`):
# ```python
# TRAJECTORY_EVALUATOR_INSTRUCTIONS = """\
# You are evaluating if an agent has followed the correct trajectory to generate a report.\
# The agent is a Report Generation Agent that uses the SQLite database tool to generate a report\
# and return the report as a downloadable file to the user.\
# You will be presented with the "Question" that has been asked to the agent along with two sets of data:\
# - The "Expected Trajectory" of the agent, which contains:\
#     - A list ids for the actions the agent is expected to perform\
#     - A list of rough descriptions of what has been passed as parameters to the actions\
# - The "Actual Trajectory" of the agent, which contains:\
#     - A list ids for the actions the agent performed\
#     - A list of parameters that has been passed to each one of the actions\
# It's OK if the agent makes mistakes and performs additional steps, or if the queries do not exactly match\
# the description, as long as the queries performed end up satisfying the "Question".\
# It is important that the last action to be of type "final_response" and that it produces a link to the report file.
# """
#
# RESULT_EVALUATOR_INSTRUCTIONS = """\
# Evaluate whether the "Proposed Answer" to the given "Question" matches the "Ground Truth". \
# Disregard the following aspects when comparing the "Proposed Answer" to the "Ground Truth": \
# - The order of the items should not matter, unless explicitly specified in the "Question". \
# - The formatting of the values should not matter, unless explicitly specified in the "Question". \
# - The column and row names have to be similar but not necessarily exact, unless explicitly specified in the "Question". \
# - The filename has to be similar by name but not necessarily exact, unless explicitly specified in the "Question". \
# - It is ok if the filename is missing. \
# - The numerical values should be equal with a tolerance of 0.01. \
# - The report data in the "Proposed Answer" should have the same number of rows as in the "Ground Truth". \
# - It is OK if the report data in the "Proposed Answer" contains extra columns or if the rows are in a different order, \
# unless explicitly specified in the "Question".
# """
# ```

# %% [markdown]
# ## Running the Evaluations
#
# To run those two evaluators against all of the ground-truth dataset samples, run the function below:

# %%
# Running as a CLI command to avoid issues between Langfuse's
# experiment runner and Jupyter
# NOTE: This will take a while to execute in a notebook environment
# It runs faster when executed in a regular console session

# !uv run --env-file .env python -m implementations.report_generation.evaluate --max-concurrency 1
# Out:
# 2026-03-24 05:13:21,947 WARNING opentelemetry.trace: Overriding of current TracerProvider is not allowed
# 2026-03-24 05:13:21,996 INFO aieng.agent_evals.langfuse: Langfuse tracing initialized successfully (endpoint: https://us.cloud.langfuse.com/api/public/otel)
# 2026-03-24 05:13:22,022 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report on the average amount spent by one time buyers for each year vs. the average custo...'
# 2026-03-24 05:13:22,187 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:23,704 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:23,704 WARNING google_genai.types: Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2026-03-24 05:13:23,849 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:26,642 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:27,754 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:30,420 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:30,428 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:13:30,553 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:32,839 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:33,166 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:36,397 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:36,405 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:13:36,532 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:39,748 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:40,446 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:42,687 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:43,017 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:45,098 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:45,664 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:47,545 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:48,158 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:13:50,437 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:13:50,444 WARNING aieng.agent_evals.report_generation.agent: Final response's content is not valid: model_version='gemini-2.5-flash' content=None grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.MALFORMED_FUNCTION_CALL: 'MALFORMED_FUNCTION_CALL'> error_code='MALFORMED_FUNCTION_CALL' error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   prompt_token_count=10896,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=10896
#     ),
#   ],
#   total_token_count=10896
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-371acbef-d2f7-41ea-874a-72d4eb937311' author='ReportGenerationAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='30120972-6dd2-423a-b228-e321a5d6bccc' timestamp=1774329228.032059
# 2026-03-24 05:13:50,444 WARNING aieng.agent_evals.report_generation.evaluation.offline: No call to `write_xlsx` function found in the agent's response
# 2026-03-24 05:13:50,589 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:13:55,070 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:14:05,721 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report on the 5 highest-value customers per year vs. the average customer....'
# 2026-03-24 05:14:05,912 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:07,735 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:07,882 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:10,359 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:11,244 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:13,681 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:14,251 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:18,129 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:18,137 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:14:18,264 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:20,570 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:21,468 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:14:23,878 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:14:24,740 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:18:21,272 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:18:21,277 WARNING aieng.agent_evals.report_generation.agent: Final response's content is not valid: model_version='gemini-2.5-flash' content=None grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.MALFORMED_FUNCTION_CALL: 'MALFORMED_FUNCTION_CALL'> error_code='MALFORMED_FUNCTION_CALL' error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   prompt_token_count=9834,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=9834
#     ),
#   ],
#   total_token_count=9834
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-6d1f4ac2-e0a7-473c-b792-b663b45645b3' author='ReportGenerationAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='49a37ee1-108a-46c5-b3ec-54355fe7b2f6' timestamp=1774329264.613833
# 2026-03-24 05:18:21,277 WARNING aieng.agent_evals.report_generation.evaluation.offline: No call to `write_xlsx` function found in the agent's response
# 2026-03-24 05:18:21,406 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:18:25,947 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:18:35,780 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report on sales revenue by country per year....'
# 2026-03-24 05:18:35,908 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:18:37,021 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:18:37,145 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:18:38,807 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:18:39,827 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:18:46,120 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:18:46,123 WARNING aieng.agent_evals.report_generation.agent: Final response's content is not valid: model_version='gemini-2.5-flash' content=None grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.MALFORMED_FUNCTION_CALL: 'MALFORMED_FUNCTION_CALL'> error_code='MALFORMED_FUNCTION_CALL' error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   prompt_token_count=2223,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2223
#     ),
#   ],
#   total_token_count=2223
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-d838a72e-7a62-4f8d-bd2a-6965687d59a5' author='ReportGenerationAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='8bd51c07-69de-4d09-bf33-706cd9783be3' timestamp=1774329519.711317
# 2026-03-24 05:18:46,123 WARNING aieng.agent_evals.report_generation.evaluation.offline: No call to `write_xlsx` function found in the agent's response
# 2026-03-24 05:18:46,242 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:18:50,031 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:18:58,116 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report with the month-over-month trends in sales. The report should include the monthly s...'
# 2026-03-24 05:18:58,243 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:00,219 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:00,337 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:02,644 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:02,651 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:19:02,770 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:05,166 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:05,173 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:19:05,289 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:07,454 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:08,198 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:14,086 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:14,089 WARNING aieng.agent_evals.report_generation.agent: Final response's content is not valid: model_version='gemini-2.5-flash' content=None grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.MALFORMED_FUNCTION_CALL: 'MALFORMED_FUNCTION_CALL'> error_code='MALFORMED_FUNCTION_CALL' error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   prompt_token_count=1949,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1949
#     ),
#   ],
#   total_token_count=1949
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-c0c80f25-01c5-4d36-a72d-bba8b9272d29' author='ReportGenerationAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='b2be9c5c-c8b1-47ab-b46e-c3dae007c4d5' timestamp=1774329548.072287
# 2026-03-24 05:19:14,090 WARNING aieng.agent_evals.report_generation.evaluation.offline: No call to `write_xlsx` function found in the agent's response
# 2026-03-24 05:19:14,216 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:19:18,859 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:19:29,253 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report of the average order value per invoice per month....'
# 2026-03-24 05:19:29,378 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:31,042 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:31,165 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:33,900 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:34,629 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:38,059 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:38,322 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:39,318 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:39,438 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:19:48,410 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:19:58,179 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a report of the top 5 selling products per year and the total sales value for each product....'
# 2026-03-24 05:19:58,303 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:19:59,122 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:19:59,257 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:00,904 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:02,587 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:04,419 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:04,425 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# 2026-03-24 05:20:04,544 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:08,602 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:09,036 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:10,618 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:11,244 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:12,786 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:13,960 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:17,865 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:17,998 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:18,998 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:19,118 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:20:32,646 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:20:43,371 INFO aieng.agent_evals.report_generation.evaluation.offline: Running agent ReportGenerationAgent with input 'Generate a monthly sales performance report....'
# 2026-03-24 05:20:43,504 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:44,905 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:45,025 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:47,446 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:48,185 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:50,822 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:50,966 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 05:20:51,793 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 05:20:51,910 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:21:01,638 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 05:21:09,452 INFO aieng.agent_evals.report_generation.evaluation.offline: Individual Results: Hidden (7 items)
# 💡 Set include_item_results=True to view them
#
# ──────────────────────────────────────────────────
# 🧪 Experiment: Evaluate Report Generation Agent
# 📋 Run name: Evaluate Report Generation Agent - 2026-03-24T05:13:21.544287Z - Evaluate the Report Generation Agent with data from Langfuse
# 7 items
# Evaluations:
#   • Final Result
#   • Trajectory
#
# Average Scores:
#   • Final Result: 0.143
#   • Trajectory: 0.429
#
# 🔗 Dataset Run:
#    https://us.cloud.langfuse.com/project/cmlsfpby6034had06phg3fq7q/datasets/cmn1kj3g707j2ad07qain6alb/runs/53afc742-4884-44f0-b87d-26b481cc94fc

# %% [markdown]
# ## Checking the Results
#
# At the end of the run, you will see a summary in the console.
#
# To see detailed results of the evaluation runs:
# 1. Go to your project on Langfuse
# 2. Click on **Datasets**
# 3. Click on the dataset name
# 4. Click on one of the runs
#
# You will see a more detailed summary of the experiment run and also you can see the details of each of of the runs, including f
